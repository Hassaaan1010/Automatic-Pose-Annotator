# %%
# final model is available at training/train/weights/best.pt

# %%
from google.colab import drive
drive.mount("/content/gdrive/")
# Out:
# Mounted at /content/gdrive/
# Mounted at /content/gdrive/

# %%
# %cd /content/gdrive/MyDrive/...
# Out:
# /content/gdrive/MyDrive/train_experiment_2_stuff

# %%
# verify train:val:test split
# !ls dataset_2.1/images/train/ | wc -l
# !ls dataset_2.1/images/val/ | wc -l
# !ls dataset_2.1/images/test/ | wc -l
# !ls dataset_2.1/labels/train/ | wc -l
# !ls dataset_2.1/labels/val/ | wc -l
# !ls dataset_2.1/labels/test/ | wc -l
# Out:
# 1590
# 400
# 102
# 1590
# 400
# 102

# %%
# !pip install ultralytics opencv-python-headless numpy torch
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 881.7/881.7 kB 44.1 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import cv2
import numpy as np
import torch
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !mkdir models/

# %%
model = YOLO("models/yolov8m-pose.pt")

# %%
# training first 100 epochs
model.train(
    project="training_trial_2.1",
    data="/content/gdrive/MyDrive/train_experiment_2_stuff/data2.yaml",  # Path to your dataset config
    epochs=100,
    patience=20,
    batch=16,
    imgsz=640,
    optimizer="Adam",
    lr0=0.001,
    weight_decay=0.0005,
    warmup_epochs=3,
    save=True,
    cache=True,
    device=0,        # Use GPU device 0
    workers=8,
    amp=True,        # Automatic Mixed Precision
    augment=True,
    val=True,
    iou=0.7,
    max_det=100
)
# Out:
# Ultralytics 8.3.2 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model = YOLO("/content/gdrive/MyDrive/...path to weights.../train/weights/last.pt")

# %%
model.train(
    project="training_trial_2.2",
    data="/content/gdrive/MyDrive/... path to yaml file .../data2.yaml",
    epochs=200,             # Continue for more epochs
    patience=20,            # Keep patience
    batch=16,
    imgsz=640,
    optimizer="Adam",
    lr0=1e-5,               # Lower learning rate
    weight_decay=0.0005,
    warmup_epochs=1,        # Reduce warmup since you've already trained
    save=True,
    cache=True,
    device=0,               # Use GPU
    workers=8,
    amp=True,               # Automatic Mixed Precision
    augment=True,
    val=True,
    iou=0.7,
    max_det=100,
    # resume=True,            # Resume training from last.pt
    save_period=10,         # Save weights every 10 epochs
    cos_lr=True             # Cosine learning rate scheduler
)
# Out:
# Ultralytics 8.3.4 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
